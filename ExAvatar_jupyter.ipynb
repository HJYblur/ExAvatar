# %% [markdown]
# <a href="https://colab.research.google.com/github/HJYblur/ExAvatar/blob/main/ExAvatar_jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt install colmap aria2 -y
# !pip install torch==2.4.0+cu124 torchvision==0.19.0+cu124 torchaudio==2.4.0+cu124 torchtext==0.18.0 torchdata==0.7.1 --extra-index-url https://download.pytorch.org/whl/cu124
# !pip install opencv-python scipy https://github.com/camenduru/wheels/releases/download/3090/pytorch3d-0.7.8-cp310-cp310-linux_x86_64.whl torchgeometry chumpy scikit-image kornia json-tricks
# !pip install https://github.com/camenduru/wheels/releases/download/3090/mmcv-2.1.0-cp310-cp310-linux_x86_64.whl mmpose mmdet numpy==1.23.5 face-alignment==1.3.4 plyfile pyrender smplx lpips
# !pip install git+https://github.com/leo-frank/diff-gaussian-rasterization-depth

# %cd /content
# !git clone https://github.com/mks0601/ExAvatar_RELEASE

# %cd /content/ExAvatar_RELEASE/fitting/tools
# !git clone https://github.com/yfeng95/DECA
# !git clone https://github.com/mks0601/Hand4Whole_RELEASE
# !git clone https://github.com/open-mmlab/mmpose
# !git clone https://github.com/facebookresearch/segment-anything
# !git clone https://github.com/DepthAnything/Depth-Anything-V2

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/SMPLer-X/resolve/main/SMPLX_FEMALE.npz -d /content/ExAvatar_RELEASE/fitting/common/utils/human_model_files/smplx -o SMPLX_FEMALE.npz
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/SMPLer-X/resolve/main/SMPLX_MALE.npz -d /content/ExAvatar_RELEASE/fitting/common/utils/human_model_files/smplx -o SMPLX_MALE.npz
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/SMPLer-X/resolve/main/SMPLX_NEUTRAL.npz -d /content/ExAvatar_RELEASE/fitting/common/utils/human_model_files/smplx -o SMPLX_NEUTRAL.npz
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/SMPLer-X/resolve/main/MANO_SMPLX_vertex_ids.pkl -d /content/ExAvatar_RELEASE/fitting/common/utils/human_model_files/smplx -o MANO_SMPLX_vertex_ids.pkl
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/SMPLer-X/resolve/main/SMPL-X__FLAME_vertex_ids.npy -d /content/ExAvatar_RELEASE/fitting/common/utils/human_model_files/smplx -o SMPL-X__FLAME_vertex_ids.npy
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/show/resolve/main/data/smplx_flip_correspondences.npz -d /content/ExAvatar_RELEASE/fitting/common/utils/human_model_files/smplx -o smplx_flip_correspondences.npz
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/show/raw/main/data/smplx_uv.obj -d /content/ExAvatar_RELEASE/fitting/common/utils/human_model_files/smplx/smplx_uv -o smplx_uv.obj
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/show/resolve/main/data/flame_dynamic_embedding.npy -d /content/ExAvatar_RELEASE/fitting/common/utils/human_model_files/flame -o flame_dynamic_embedding.npy
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/show/resolve/main/data/flame/FLAME_FEMALE.pkl -d /content/ExAvatar_RELEASE/fitting/common/utils/human_model_files/flame -o FLAME_FEMALE.pkl
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/show/resolve/main/data/flame/FLAME_MALE.pkl -d /content/ExAvatar_RELEASE/fitting/common/utils/human_model_files/flame -o FLAME_MALE.pkl
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/show/resolve/main/data/flame/FLAME_NEUTRAL.pkl -d /content/ExAvatar_RELEASE/fitting/common/utils/human_model_files/flame -o FLAME_NEUTRAL.pkl
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/show/resolve/main/data/flame/flame_static_embedding.pkl -d /content/ExAvatar_RELEASE/fitting/common/utils/human_model_files/flame -o flame_static_embedding.pkl
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/show/resolve/main/data/flame/FLAME_texture.npz -d /content/ExAvatar_RELEASE/fitting/common/utils/human_model_files/flame -o FLAME_texture.npz
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/show/resolve/main/data/flame/2019/generic_model.pkl -d /content/ExAvatar_RELEASE/fitting/common/utils/human_model_files/flame/2019 -o generic_model.pkl

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/SMPLer-X/resolve/main/SMPL_NEUTRAL.pkl -d /content/ExAvatar_RELEASE/fitting/tools/Hand4Whole_RELEASE/common/utils/human_model_files/smpl -o SMPL_NEUTRAL.pkl
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/SMPLer-X/resolve/main/SMPLX_to_J14.pkl -d /content/ExAvatar_RELEASE/fitting/tools/Hand4Whole_RELEASE/common/utils/human_model_files/smplx -o SMPLX_to_J14.pkl
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/show/resolve/main/data/mano/MANO_LEFT.pkl -d /content/ExAvatar_RELEASE/fitting/tools/Hand4Whole_RELEASE/common/utils/human_model_files/mano -o MANO_LEFT.pkl
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/show/resolve/main/data/mano/MANO_RIGHT.pkl -d /content/ExAvatar_RELEASE/fitting/tools/Hand4Whole_RELEASE/common/utils/human_model_files/mano -o MANO_RIGHT.pkl
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/show/resolve/main/data/flame/FLAME_NEUTRAL.pkl -d /content/ExAvatar_RELEASE/fitting/tools/Hand4Whole_RELEASE/common/utils/human_model_files/flame -o FLAME_NEUTRAL.pkl
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/show/resolve/main/data/flame_dynamic_embedding.npy -d /content/ExAvatar_RELEASE/fitting/tools/Hand4Whole_RELEASE/common/utils/human_model_files/flame -o flame_dynamic_embedding.npy
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/show/resolve/main/data/flame/flame_static_embedding.pkl -d /content/ExAvatar_RELEASE/fitting/tools/Hand4Whole_RELEASE/common/utils/human_model_files/flame -o flame_static_embedding.pkl
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/SMPLer-X/resolve/main/MANO_SMPLX_vertex_ids.pkl -d /content/ExAvatar_RELEASE/fitting/tools/Hand4Whole_RELEASE/common/utils/human_model_files/smplx -o MANO_SMPLX_vertex_ids.pkl
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/SMPLer-X/resolve/main/SMPL-X__FLAME_vertex_ids.npy -d /content/ExAvatar_RELEASE/fitting/tools/Hand4Whole_RELEASE/common/utils/human_model_files/smplx -o SMPL-X__FLAME_vertex_ids.npy
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/SMPLer-X/resolve/main/SMPLX_NEUTRAL.pkl -d /content/ExAvatar_RELEASE/fitting/tools/Hand4Whole_RELEASE/common/utils/human_model_files/smplx -o SMPLX_NEUTRAL.pkl
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/SMPLer-X/resolve/main/SMPLX_NEUTRAL.npz -d /content/ExAvatar_RELEASE/fitting/tools/Hand4Whole_RELEASE/common/utils/human_model_files/smplx -o SMPLX_NEUTRAL.npz
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/SMPLer-X/resolve/main/SMPLX_MALE.npz -d /content/ExAvatar_RELEASE/fitting/tools/Hand4Whole_RELEASE/common/utils/human_model_files/smplx -o SMPLX_MALE.npz
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/SMPLer-X/resolve/main/SMPLX_FEMALE.npz -d /content/ExAvatar_RELEASE/fitting/tools/Hand4Whole_RELEASE/common/utils/human_model_files/smplx -o SMPLX_FEMALE.npz
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/SMPLer-X/resolve/main/SMPL_MALE.pkl -d /content/ExAvatar_RELEASE/fitting/tools/Hand4Whole_RELEASE/common/utils/human_model_files/smpl -o SMPL_MALE.pkl
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/SMPLer-X/resolve/main/SMPL_FEMALE.pkl -d /content/ExAvatar_RELEASE/fitting/tools/Hand4Whole_RELEASE/common/utils/human_model_files/smpl -o SMPL_FEMALE.pkl

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://download.openmmlab.com/mmpose/v1/projects/rtmpose/rtmdet_m_8xb32-100e_coco-obj365-person-235e8209.pth -d /content/ExAvatar_RELEASE/fitting/tools/mmpose -o rtmdet_m_8xb32-100e_coco-obj365-person-235e8209.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/yzd-v/DWPose/resolve/main/dw-ll_ucoco_384.pth -d /content/ExAvatar_RELEASE/fitting/tools/mmpose -o dw-ll_ucoco_384.pth

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/HCMUE-Research/SAM-vit-h/resolve/main/sam_vit_h_4b8939.pth -d /content/ExAvatar_RELEASE/fitting/tools/segment-anything -o sam_vit_h_4b8939.pth

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/depth-anything/Depth-Anything-V2-Large/resolve/main/depth_anything_v2_vitl.pth -d /content/ExAvatar_RELEASE/fitting/tools/Depth-Anything-V2/checkpoints -o depth_anything_v2_vitl.pth

# !cp /content/ExAvatar_RELEASE/fitting/common/utils/human_model_files/flame/2019/generic_model.pkl /content/ExAvatar_RELEASE/fitting/tools/DECA/data/generic_model.pkl
# !cp -r /content/ExAvatar_RELEASE/fitting/common/utils/human_model_files /content/ExAvatar_RELEASE/avatar/common/utils/human_model_files

# !sed -i.bak 's/1 - mask_d0_d1/~mask_d0_d1/' /content/ExAvatar-venv/lib/python3.10/site-packages/torchgeometry/core/conversions.py
# !sed -i.bak 's/\(1 - \)\(mask_[^ ]*\)/~\2/g' /content/ExAvatar-venv/lib/python3.10/site-packages/torchgeometry/core/conversions.py
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libamd2 libaria2-0 libc-ares2 libcamd2 libccolamd2 libceres2 libcholmod3
#   libcolamd2 libcxsparse3 libevdev2 libfreeimage3 libgflags2.2
#   libgoogle-glog0v5 libgudev-1.0-0 libinput-bin libinput10 libjxr0 libmd4c0
#   libmetis5 libmtdev1 libqt5core5a libqt5dbus5 libqt5gui5 libqt5network5
#   libqt5svg5 libqt5widgets5 libraw20 libspqr2 libsuitesparseconfig5
#   libwacom-bin libwacom-common libwacom9 libxcb-icccm4 libxcb-image0
#   libxcb-keysyms1 libxcb-render-util0 libxcb-util1 libxcb-xinerama0
#   libxcb-xinput0 libxcb-xkb1 libxkbcommon-x11-0 qt5-gtk-platformtheme
#   qttranslations5-l10n
# Suggested packages:
#   qt5-image-formats-plugins qtwayland5
# The following NEW packages will be installed:
#   aria2 colmap libamd2 libaria2-0 libc-ares2 libcamd2 libccolamd2 libceres2
# ...

# %%
# %cd /content/ExAvatar_RELEASE/fitting/tools
# !python copy_code.py
# download the video
# !python extract_frames.py --root_path /content/ExAvatar_RELEASE/fitting/data/Custom/data/gyeongsik
# create frame_list_all.txt
# !python run.py --root_path /content/ExAvatar_RELEASE/fitting/data/Custom/data/gyeongsik

# %%
# %cd /content/ExAvatar_RELEASE/fitting/tools

import os
import os.path as osp
from glob import glob

root_path = "/content/ExAvatar_RELEASE/fitting/data/Custom/data/gyeongsik"
if root_path[-1] == '/':
    subject_id = root_path.split('/')[-2]
else:
    subject_id = root_path.split('/')[-1]

# remove unnecessary frames
with open(osp.join(root_path, 'frame_list_all.txt')) as f:
    frame_idx_list = [int(x) for x in f.readlines()]
img_path_list = glob(osp.join(root_path, 'frames', '*.png'))
for img_path in img_path_list:
    frame_idx = int(img_path.split('/')[-1][:-4])
    if frame_idx not in frame_idx_list:
        cmd = 'rm ' + img_path
        os.system(cmd)

# make camera parameters
cmd = 'python make_virtual_cam_params.py --root_path ' + root_path
print(cmd)
os.system(cmd)

# DECA (get initial FLAME parameters)
os.chdir('./DECA')
cmd = 'python run_deca.py --root_path ' + root_path
print(cmd)
os.system(cmd)
os.chdir('..')

# Hand4Whole (get initial SMPLX parameters)
os.chdir('./Hand4Whole_RELEASE/demo')
cmd = 'python run_hand4whole.py --gpu 0 --root_path ' + root_path
print(cmd)
os.system(cmd)
os.chdir('../../')

# mmpose (get 2D whole-body keypoints)
os.chdir('./mmpose')
cmd = 'python run_mmpose.py --root_path ' + root_path
print(cmd)
os.system(cmd)
os.chdir('..')

# fit SMPLX
os.chdir('../main')
cmd = 'python fit.py --subject_id ' + subject_id
print(cmd)
os.system(cmd)
os.chdir('../tools')
cmd = 'mv ' + osp.join('..', 'output', 'result', subject_id, '*') + ' ' + osp.join(root_path, '.')
print(cmd)
os.system(cmd)

# # unwrap textures of FLAME
# os.chdir('../main')
# cmd = 'python unwrap.py --subject_id ' + subject_id
# print(cmd)
# os.system(cmd)
# os.chdir('../tools')
# cmd = 'mv ' + osp.join('..', 'output', 'result', subject_id, 'unwrapped_textures', '*') + ' ' + osp.join(root_path, 'smplx_optimized', '.')
# os.system(cmd)

# smooth SMPLX
cmd = 'python smooth_smplx_params.py --root_path ' + root_path
print(cmd)
os.system(cmd)

# %%
# %cd /content/ExAvatar_RELEASE/fitting/tools/segment-anything
# !python run_sam.py --root_path ../../data/Custom/data/gyeongsik

# %cd /content/ExAvatar_RELEASE/fitting/tools/Depth-Anything-V2
# !python run_depth_anything.py --root_path ../../data/Custom/data/gyeongsik

# %%
# %cd /content/ExAvatar_RELEASE/avatar/main
# !python train.py --subject_id gyeongsik
